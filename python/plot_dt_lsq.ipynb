# %%
import numpy as np
import matplotlib.pyplot as pl
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
d = np.loadtxt('../res/dt_lsq',skiprows=1)

# %%
fig = pl.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(d[:,1], d[:,3], d[:,2])
ax.set_xlabel('x')
ax.set_ylabel('z')
ax.set_zlabel('y')

# %%
pl.plot(d[:,1],d[:,2],'o')
pl.xlabel('x')
pl.ylabel('y')

# %%
pl.plot(d[:,2],d[:,3],'o')
pl.xlabel('y')
pl.ylabel('z')

# %%
pl.plot(d[:,3],d[:,1],'o')
pl.xlabel('z')
pl.ylabel('x')
